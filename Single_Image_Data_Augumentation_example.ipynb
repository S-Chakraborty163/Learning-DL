# %%
pip install image
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 92.9 MB/s eta 0:00:00
# ...
#   Created wheel for image: filename=image-1.5.33-py2.py3-none-any.whl size=19482 sha256=fa663668e928e9971652631e3d3d055f9ee42dbd0636faa9e52e1f1d1d4a37bb
#   Stored in directory: /root/.cache/pip/wheels/58/30/d8/3212cd83eeeeee0a1f0c7b9b7bd0674a2b9f09342870473a2a
# Successfully built image
# ...

# %%
import tensorflow as tf
from tensorflow import keras

# %%
from keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
img = image.load_img('/content/cat.194.jpg',target_size=(200,200))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=200x200>

# %%
type(img)
# Out:
# PIL.Image.Image

# %%
datagen = ImageDataGenerator(
    rotation_range=30,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    width_shift_range=0.2,
    height_shift_range=0.2,


)

# %%
img = image.img_to_array(img)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (200, 200, 3)

# %%
input_batch = img.reshape(1,200,200,3)

# %%
i=0

for output in datagen.flow(input_batch,batch_size=1,save_to_dir='aug'):

  i = i+1

  if i == 10:
    break

# %%
input_batch.shape
# Out:
# (1, 200, 200, 3)

# %%
img1 = image.load_img('/content/aug/_0_1205.png',target_size=(200,200))
img2 = image.load_img('/content/aug/_0_1746.png',target_size=(200,200))
img3 = image.load_img('/content/aug/_0_222.png',target_size=(200,200))
img4 = image.load_img('/content/aug/_0_2395.png',target_size=(200,200))
img5 = image.load_img('/content/aug/_0_3277.png',target_size=(200,200))
img6 = image.load_img('/content/aug/_0_4645.png',target_size=(200,200))
img7 = image.load_img('/content/aug/_0_5669.png',target_size=(200,200))
img8 = image.load_img('/content/aug/_0_6241.png',target_size=(200,200))
img9 = image.load_img('/content/aug/_0_6258.png',target_size=(200,200))
img10 = image.load_img('/content/aug/_0_6354.png',target_size=(200,200))

# %%
img1
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=200x200>

# %%
img2
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=200x200>

# %%
img3
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=200x200>

# %%
img4
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=200x200>

# %%
img5
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=200x200>

# %%
img6
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=200x200>

# %%
img7
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=200x200>

# %%
img8
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=200x200>

# %%
img9
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=200x200>

# %%
img10
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=200x200>
